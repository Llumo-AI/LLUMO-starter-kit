# %% [markdown]
# # 📘 **Colab Notebook: Input Evaluation Using Llumo**
#
# ---
#
# ### 📝 **Notebook Overview**
#
# This notebook helps you **evaluate input queries** using Llumo’s powerful input-level metrics to ensure quality and safety:
#
# ✨ **Metrics included:**
# - **Input Bias** ⚖️
# - **Input Relevancy** 🔍
# - **Input Toxicity** ☣️
# - **Input Harmfulness** 🚫
#
# ---
#
# ### 🚀 **What you will do in this notebook:**
# 1. 📂 Load input data from an Excel file
# 2. 🤖 Evaluate the queries for bias, relevancy, toxicity, and harmfulness
# 3. 📊 View the detailed evaluation results
#
# ---
#
# 🔐 **Note:** The Llumo API key will be securely requested during runtime using Colab’s input prompt.

# %% [markdown]
# # ⚙️ **Step 1: Install Dependencies**

# %%
# !pip install llumo -q

# %% [markdown]
# # 📂 **Step 2: Import Required Libraries**

# %%
import pandas as pd
from llumo import LlumoClient
import getpass
import os

# %% [markdown]
# # 🧾 **Step 3: Load the Dataset**

# %%
# Make sure 'data.xlsx' is uploaded to your Colab environment
df = pd.read_excel("data.xlsx")

# Preview the data
df.head()
# Out:
#                                              context  \
# 0  ElectraTech is your go-to destination for the ...
# 1  FutureGadgets is your source for the most adva...
# 2  CyberShield Solutions is a premier provider of...
# 3  TechFuture is where innovation meets quality. ...
# 4  HiTechHub is where we offer the latest and mos...
#
#                                                query  \
# 0  How can I return a laptop if I am not satisfie...
# 1  What do I do if my product arrives with a defect?
# 2         How does CyberShield handle a data breach?
# 3       What do I do if my product is missing parts?
# 4  Can I return a product if I’ve opened the pack...
#
#                                               output
# 0  ElectraTech accepts returns within 30 days if ...
# 1  Contact FutureGadgets customer service to repo...
# 2  CyberShield's response to a data breach would ...
# 3  Contact TechFuture's 24/7 customer support for...
# 4  No. HiTechHub's return policy requires the ite...

# %% [markdown]
# # 🔐 **Step 4: Enter Llumo API Key Securely**

# %%
# Prompt user to input their API key securely (won't be visible in output)
os.environ["LLUMO_API_KEY"] = getpass.getpass("Enter your Llumo API key: ")

# Retrieve the API key
llumo_key = os.environ["LLUMO_API_KEY"]
# Out:
# Enter your Llumo API key: ··········

# %% [markdown]
# # 🤖 **Step 5: Initialize Llumo Client And Evaluate**

# %%
# Create an instance of the LlumoClient
client = LlumoClient(llumo_key)


# Evaluate the queries using input-level metrics
resultDf = client.evaluateMultiple(
    dataframe = df,  # DataFrame to evaluate. Must include columns used in prompt_template (e.g., 'query', 'context')
    eval = ["Input Bias", "Input Relevancy", "Input Toxicity", "Input Harmfulness"], # List of input metrics
    prompt_template = "Give answer to the query: {{query}}, using context: {{context}}.",  # Prompt pattern used while evaluating. The column names inside {{}} must exist in the DataFrame.This should match the format used during response generation.
    createExperiment = False   # Set to True to save results as an experiment on the Llumo platform. If False, returns results as a DataFrame.

)
# Out:
# ======= Running evaluation for: Input Bias =======
#
# ======= Running evaluation for: Input Relevancy =======
#
# ======= Running evaluation for: Input Toxicity =======
#
# ======= Running evaluation for: Input Harmfulness =======

# %% [markdown]
# # 📊 **Step 6: View Evaluation Results**

# %%
# Show the results with added metric columns
resultDf.head()
# Out:
#                                              context  \
# 0  ElectraTech is your go-to destination for the ...
# 1  FutureGadgets is your source for the most adva...
# 2  CyberShield Solutions is a premier provider of...
# 3  TechFuture is where innovation meets quality. ...
# 4  HiTechHub is where we offer the latest and mos...
#
#                                                query  \
# 0  How can I return a laptop if I am not satisfie...
# 1  What do I do if my product arrives with a defect?
# 2         How does CyberShield handle a data breach?
# 3       What do I do if my product is missing parts?
# 4  Can I return a product if I’ve opened the pack...
#
#                                               output Input Bias  \
# 0  ElectraTech accepts returns within 30 days if ...          2
# 1  Contact FutureGadgets customer service to repo...          1
# 2  CyberShield's response to a data breach would ...          1
# 3  Contact TechFuture's 24/7 customer support for...          1
# 4  No. HiTechHub's return policy requires the ite...          1
#
#                                    Input Bias Reason Input Relevancy  \
# 0  The query is neutral and does not contain any ...             100
# 1  The query is neutral and seeks a solution to a...              99
# 2  The input is a request for information, not an...             100
# 3  The query is neutral and requests a solution t...              91
# 4  The input query is a neutral question about pr...              99
#
#                               Input Relevancy Reason Input Toxicity  \
# 0  The query directly asks about returns, a topic...             12
# 1  The query directly asks about product defects,...             14
# 2  The query directly asks about CyberShield's da...             17
# 3  The query directly relates to the context's su...             13
# 4  The query directly addresses the context's ret...             19
#
#                                Input Toxicity Reason Input Harmfulness  \
# 0  The input is a request for information, lackin...                15
# 1  The input lacks abusive language, discriminati...                 2
# 2  The input is a request for information, lackin...                 2
# 3  The input is a neutral request for information...                21
# 4  The input is a neutral request for information...                 1
#
#                             Input Harmfulness Reason
# 0  The query is neutral and seeks information on ...
# 1  The input is a request for information on hand...
# 2  The input is a request for information, not ha...
# 3  The query is neutral; it seeks help for a prob...
# 4  The input is a request for information on prod...

# %% [markdown]
# # 🔍 **Data Retrieval Using LlumoClient**
#  ---
# 📘 **Notebook Overview:**
#
#  This notebook demonstrates how to perform similarity-based data retrieval using the LlumoClient SDK. It leverages a pre-configured data stream to fetch relevant results for each input query from the provided dataset.
#
# **You simply need to:**
#
# - Load your data containing the queries
#
# - Provide the appropriate stream configuration
#
# - Fetch similar data entries automatically using the built-in API call
#
# No manual tuning or complex configurations are required—just plug in your data and query column, and the API handles the rest efficiently.
#
# ---

# %% [markdown]
# #**⬇ Step 1: Necessary Installation**

# %%
# !pip install llumo -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.0/647.0 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 5.9 MB/s eta 0:00:00

# %% [markdown]
# # 🔐 **Step 2: Load Llumo API Key**

# %%
import os

# Set your OpenAI API Key
os.environ["OPENAI_API_KEY"] = "Enter Your Open API Key"

# Set your Llumo API Key
os.environ["LLUMO_API_KEY"] = "Enter Your LLumo Key"

openai_key = os.getenv("OPENAI_API_KEY")
llumo_key = os.getenv("LLUMO_API_KEY")

# %% [markdown]
# # 📦 **Step 3: Import required libraries**

# %%
import pandas as pd
from llumo import LlumoClient
from google.colab import userdata

# %% [markdown]
# #📋  **Step 4: Importing the data file**

# %%
# upload your data file using pandas

data = [
    {"query":"What is the capital of France?"},
    {"query":"Where is the Eiffel Tower located?"},
    {"query":"What is the largest planet in our solar system?"},
    {"query":"Who is the current president of the United States?"}
]

# %% [markdown]
# # **🚀 Step 5: Fetch data from the data stream**
#
# - start the searching by specifying the stream name.
# -  you can find the strean name after logging into https://llumo.ai/
# - the dataframe should have a query column - based on which the searching will be performed.

# %%
# Initialize LlumoClient
client = LlumoClient(api_key=api_key)

# start fetching
output_df = client.runDataStream(
    data = data, # Input Data
    streamName = "datastream_name_here", # name with which the data was upload on llumo.ai
    queryColName = "query_column_name_here" # name of the query column. Must be "query" if you want to peform any evaluation on this data later on.
    createExperiment = False,   # Set to True to save results as an experiment on the Llumo platform. If False, returns results as a DataFrame or A Python Dict.
    getDataFrame = True, # Return result as a DataFrame (True) or dictionary (False)

)
# Out:
# ====🚀Sit back while we fetch data from the stream 🚀====
# =======You are all set! continue your expectations 🚀======

# %% [markdown]
# # **📊 Display the output DataFrame**

# %%
# Display the first rows
output_df.head()
